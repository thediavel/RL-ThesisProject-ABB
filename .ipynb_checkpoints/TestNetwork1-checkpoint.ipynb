# %%
import pandapower as pp
import pandapower.networks
from pandapower.plotting import simple_plot

# Predefined network of IEEE 5 bus system
net = pp.networks.case5()
simple_plot(net)

# %%
net.bus
# Out:
#    in_service  max_vm_pu  min_vm_pu name type  vn_kv zone
# 0        True        1.1        0.9    0    b  230.0    1
# 1        True        1.1        0.9    1    b  230.0    1
# 2        True        1.1        0.9    2    b  230.0    1
# 3        True        1.1        0.9    3    b  230.0    1
# 4        True        1.1        0.9    4    b  230.0    1

# %%
net.load
# Out:
#    bus  const_i_percent  const_z_percent  controllable  in_service  name  \
# 0    1              0.0              0.0         False        True  None
# 1    2              0.0              0.0         False        True  None
# 2    3              0.0              0.0         False        True  None
#
#     p_mw  q_mvar  scaling  sn_mva  type
# 0  300.0   98.61      1.0     NaN  None
# 1  300.0   98.61      1.0     NaN  None
# 2  400.0  131.47      1.0     NaN  None

# %%
net.trafo
# Out:
# Empty DataFrame
# Columns: [name, std_type, hv_bus, lv_bus, sn_mva, vn_hv_kv, vn_lv_kv, vk_percent, vkr_percent, pfe_kw, i0_percent, shift_degree, tap_side, tap_neutral, tap_min, tap_max, tap_step_percent, tap_step_degree, tap_pos, tap_phase_shifter, parallel, df, in_service]
# Index: []
#
# [0 rows x 23 columns]

# %%
net.line
# Out:
#    c_nf_per_km   df  from_bus  g_us_per_km  in_service  length_km  \
# 0    35.702054  1.0         0          0.0        True        1.0
# 1    32.994314  1.0         0          0.0        True        1.0
# 2   156.748063  1.0         0          0.0        True        1.0
# 3    92.865455  1.0         1          0.0        True        1.0
# 4    33.796607  1.0         2          0.0        True        1.0
# 5    33.796607  1.0         3          0.0        True        1.0
#
#        max_i_ka  max_loading_percent  name  parallel  r_ohm_per_km std_type  \
# 0      1.004087                100.0  None         1       1.48649     None
# 1  99999.000000                100.0  None         1       1.60816     None
# 2  99999.000000                100.0  None         1       0.33856     None
# 3  99999.000000                100.0  None         1       0.57132     None
# 4  99999.000000                100.0  None         1       1.57113     None
# 5      0.602452                100.0  None         1       1.57113     None
#
#    to_bus type  x_ohm_per_km
# 0       1   ol       14.8649
# 1       3   ol       16.0816
# 2       4   ol        3.3856
# 3       2   ol        5.7132
# 4       3   ol       15.7113
# 5       4   ol       15.7113

# %%
net.gen
# Out:
#    bus  controllable  in_service  name    p_mw  scaling  sn_mva  type  vm_pu  \
# 0    0          True        True  None   40.00      1.0     NaN  None    1.0
# 1    2          True        True  None  323.49      1.0     NaN  None    1.0
# 2    4          True        True  None  466.51      1.0     NaN  None    1.0
#
#    slack  max_p_mw  min_p_mw  max_q_mvar  min_q_mvar
# 0  False      40.0       0.0        30.0       -30.0
# 1  False     520.0       0.0       390.0      -390.0
# 2  False     600.0       0.0       450.0      -450.0

# %%
net.ext_grid
# Out:
#    bus  in_service  name  va_degree  vm_pu  max_p_mw  min_p_mw  max_q_mvar  \
# 0    3        True  None        0.0    1.0     200.0       0.0       150.0
#
#    min_q_mvar
# 0      -150.0

# %%
pp.runpp(net)

# %%
net.res_bus
# Out:
#       vm_pu  va_degree       p_mw     q_mvar
# 0  1.000000   3.273361 -210.00000 -30.725160
# 1  0.989261  -0.759269  300.00000  98.610000
# 2  1.000000  -0.492259  -23.49000 -96.044720
# 3  1.000000   0.000000  394.97282 -52.652930
# 4  1.000000   4.112031 -466.51000  38.209623

# %%
net.res_load
# Out:
#     p_mw  q_mvar
# 0  300.0   98.61
# 1  300.0   98.61
# 2  400.0  131.47

# %%
net.res_line
# Out:
#     p_from_mw  q_from_mvar     p_to_mw  q_to_mvar     pl_mw    ql_mvar  \
# 0  249.773373    21.599095 -248.006760  -4.637368  1.766612  16.961728
# 1  186.500142   -13.612148 -185.437396  23.581606  1.062746   9.969458
# 2 -226.273515    22.738212  226.604972 -22.549636  0.331458   0.188576
# 3  -51.993240   -93.972632   52.118657  93.394588  0.125417  -0.578044
# 4  -28.628657     2.650132   28.653264  -3.078060  0.024607  -0.427929
# 5 -238.188688    32.149384  239.905028 -15.659987  1.716340  16.489397
#
#    i_from_ka   i_to_ka      i_ka  vm_from_pu  va_from_degree  vm_to_pu  \
# 0   0.629326  0.629419  0.629419    1.000000        3.273361  0.989261
# 1   0.469401  0.469237  0.469401    1.000000        3.273361  1.000000
# 2   0.570857  0.571637  0.571637    1.000000        3.273361  1.000000
# 3   0.272517  0.268475  0.272517    0.989261       -0.759269  1.000000
# 4   0.072171  0.072340  0.072340    1.000000       -0.492259  1.000000
# 5   0.603327  0.603496  0.603496    1.000000        0.000000  1.000000
#
#    va_to_degree  loading_percent
# 0     -0.759269        62.685695
# 1      0.000000         0.000469
# 2      4.112031         0.000572
# 3     -0.492259         0.000273
# 4      0.000000         0.000072
# 5      4.112031       100.173164

# %%
net.res_ext_grid
# Out:
#       p_mw     q_mvar
# 0  5.02718  184.12293
